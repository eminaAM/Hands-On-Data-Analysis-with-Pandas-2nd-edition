# %% [markdown]
# <a href="https://colab.research.google.com/github/eminaAM/Hands-On-Data-Analysis-with-Pandas-2nd-edition/blob/master/homework_cchbc_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
url = "https://data.cityofnewyork.us/api/views/25th-nujf/rows.csv"

# %%
import pandas as pd

# %%
dataset=pd.read_csv(url)

# %%
dataset.head()
# Out:
#    Year of Birth  Gender Ethnicity Child's First Name  Count  Rank
# 0           2011  FEMALE  HISPANIC          GERALDINE     13    75
# 1           2011  FEMALE  HISPANIC                GIA     21    67
# 2           2011  FEMALE  HISPANIC             GIANNA     49    42
# 3           2011  FEMALE  HISPANIC            GISELLE     38    51
# 4           2011  FEMALE  HISPANIC              GRACE     36    53

# %%
dataset.to_csv("ny_")

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-623a8651-1221-4466-88b5-e4b9bac39f6f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-623a8651-1221-4466-88b5-e4b9bac39f6f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv('UDTpirs.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-2-1fdba3f95fe2> in <cell line: 0>()
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('UDTpirs.csv')
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd

# Try reading the file with 'latin-1' encoding
df = pd.read_csv('UDTpirs.csv', encoding='latin-1')

# If 'latin-1' doesn't work, try other encodings like 'ISO-8859-1', 'cp1252', etc.
# df = pd.read_csv('UDTpirs.csv', encoding='ISO-8859-1')
# df = pd.read_csv('UDTpirs.csv', encoding='cp1252')

# You can also use the 'chardet' library to automatically detect the encoding
# !pip install chardet
# import chardet
# with open('UDTpirs.csv', 'rb') as f:
#     result = chardet.detect(f.read())
# encoding = result['encoding']
# df = pd.read_csv('UDTpirs.csv', encoding=encoding)

# %%
# !head UDTpirs.csv
# Out:
# *ITEM;ItemDescr;*SUPPLIER;*LOC;LEADTIME;MINQTY;UD_PRIORITY;UD_LEADTIME;UD_MINQTY;UD_INCORDERQTY;ItemClass;U_MATERIAL_GROUP_DESCR;U_ITEM_CATEGORY_DESCR;U_SOURCE
# 12000007;GAS NITROGEN;4000040057;8610;7;60;;7;;;ZRW;RM&P_IGR_GAS/OIL CO2;;Y
# 12000073;CONC COCA-COLA PART 1;3000000088;8610;21;8;;7;;;ZRW;RM&P_IGR_CONC TCCC;;Y
# 12000112;CROWN COCA-COLA;4000003264;8610;21;385.000;;7;;;ZRW;RM&P_PPA_CRWS;;Y
# 12000112;CROWN COCA-COLA;4000018880;8610;21;400.000;;7;;;ZRW;RM&P_PPA_CRWS;;Y
# 12000112;CROWN COCA-COLA;4000030283;8610;21;400.000;;7;;;ZRW;RM&P_PPA_CRWS;;Y
# 12000115;CROWN FANTA ORG;2000000026;8610;15;0;;7;;;ZRW;RM&P_PPA_CRWS;;Y
# 12000115;CROWN FANTA ORG;4000003264;8610;21;385.000;;7;;;ZRW;RM&P_PPA_CRWS;;Y
# 12000115;CROWN FANTA ORG;4000018880;8610;21;400.000;;7;;;ZRW;RM&P_PPA_CRWS;;Y
# 12000115;CROWN FANTA ORG;4000030283;8610;21;400.000;;7;;;ZRW;RM&P_PPA_CRWS;;Y

# %%
from google.colab import files

uploaded = files.upload()

# Get the filename of the uploaded file
filename = list(uploaded.keys())[0]

# Read the Excel file using pandas
import pandas as pd
df = pd.read_excel(filename)

# Display the first few rows of the DataFrame
df.head()
# Out:
#      <input type="file" id="files-9c470895-ccf0-4c5f-9269-8e2fc08ca39e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9c470895-ccf0-4c5f-9269-8e2fc08ca39e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
